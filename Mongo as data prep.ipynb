# %% [markdown]
# ## Mongo as data prep
#
# This is some discovery work to start to identify how we can execute data preprocessing jobs in MongoDB.

# %%
# %pprint
# Out:
# Pretty printing has been turned ON

# %% [markdown]
# ## Necessary dependecies

# %%
# %pip install docker pymongo pandas
# Out:
# Requirement already satisfied: docker in /home/david/.pyenv/versions/3.8.2/envs/mongo-data-prep/lib/python3.8/site-packages (4.2.0)
# Requirement already satisfied: pymongo in /home/david/.pyenv/versions/3.8.2/envs/mongo-data-prep/lib/python3.8/site-packages (3.10.1)
# Requirement already satisfied: pandas in /home/david/.pyenv/versions/3.8.2/envs/mongo-data-prep/lib/python3.8/site-packages (1.0.3)
# Requirement already satisfied: websocket-client>=0.32.0 in /home/david/.pyenv/versions/3.8.2/envs/mongo-data-prep/lib/python3.8/site-packages (from docker) (0.57.0)
# Requirement already satisfied: six>=1.4.0 in /home/david/.pyenv/versions/3.8.2/envs/mongo-data-prep/lib/python3.8/site-packages (from docker) (1.14.0)
# Requirement already satisfied: requests!=2.18.0,>=2.14.2 in /home/david/.pyenv/versions/3.8.2/envs/mongo-data-prep/lib/python3.8/site-packages (from docker) (2.23.0)
# Requirement already satisfied: numpy>=1.13.3 in /home/david/.pyenv/versions/3.8.2/envs/mongo-data-prep/lib/python3.8/site-packages (from pandas) (1.18.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in /home/david/.pyenv/versions/3.8.2/envs/mongo-data-prep/lib/python3.8/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /home/david/.pyenv/versions/3.8.2/envs/mongo-data-prep/lib/python3.8/site-packages (from pandas) (2020.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/david/.pyenv/versions/3.8.2/envs/mongo-data-prep/lib/python3.8/site-packages (from requests!=2.18.0,>=2.14.2->docker) (1.25.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/david/.pyenv/versions/3.8.2/envs/mongo-data-prep/lib/python3.8/site-packages (from requests!=2.18.0,>=2.14.2->docker) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /home/david/.pyenv/versions/3.8.2/envs/mongo-data-prep/lib/python3.8/site-packages (from requests!=2.18.0,>=2.14.2->docker) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in /home/david/.pyenv/versions/3.8.2/envs/mongo-data-prep/lib/python3.8/site-packages (from requests!=2.18.0,>=2.14.2->docker) (2020.4.5.1)
# WARNING: You are using pip version 19.2.3, however version 20.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Run a mongo container

# %%
import os
import docker

docker_client = docker.from_env()

mongo_container = docker_client.containers.run(
    'mongo:latest',
    detach=True,
    name='mongo-data-prep',
    remove=True,
    ports={'27017/tcp': 27018},
    mem_limit='512M',
    volumes={
        os.path.join(os.getcwd(), 'db'): {'bind': '/data/db', 'mode': 'rw'},
        os.path.join(os.getcwd(), 'mongo.conf'): {'bind': '/etc/mongo.conf', 'mode': 'ro'}
    }
)

# %% [markdown]
# To get its state:

# %%
mongo_container.logs()
# Out:
# b'2020-05-02T12:46:04.050+0000 I  CONTROL  [main] Automatically disabling TLS 1.0, to force-enable TLS 1.0 specify --sslDisabledProtocols \'none\'\n2020-05-02T12:46:04.057+0000 W  ASIO     [main] No TransportLayer configured during NetworkInterface startup\n2020-05-02T12:46:04.057+0000 I  CONTROL  [initandlisten] MongoDB starting : pid=1 port=27017 dbpath=/data/db 64-bit host=ca620174dbc5\n2020-05-02T12:46:04.057+0000 I  CONTROL  [initandlisten] db version v4.2.5\n2020-05-02T12:46:04.057+0000 I  CONTROL  [initandlisten] git version: 2261279b51ea13df08ae708ff278f0679c59dc32\n2020-05-02T12:46:04.057+0000 I  CONTROL  [initandlisten] OpenSSL version: OpenSSL 1.1.1  11 Sep 2018\n2020-05-02T12:46:04.057+0000 I  CONTROL  [initandlisten] allocator: tcmalloc\n2020-05-02T12:46:04.057+0000 I  CONTROL  [initandlisten] modules: none\n2020-05-02T12:46:04.057+0000 I  CONTROL  [initandlisten] build environment:\n2020-05-02T12:46:04.057+0000 I  CONTROL  [initandlisten]     distmod: ubuntu1804\n2020-05-02T12:46:04.057+0000 I  CONTROL  [initandlisten]     distarch: x86_64\n2020-05-02T12:46:04.057+0000 I  CONTROL  [initandlisten]     target_arch: x86_64\n2020-05-02T12:46:04.057+0000 I  CONTROL  [initandlisten] 256 MB of memory available to the process out of 15829 MB total system memory\n2020-05-02T12:46:04.057+0000 I  CONTROL  [initandlisten] options: { net: { bindIp: "*" } }\n2020-05-02T12:46:04.058+0000 W  STORAGE  [initandlisten] Detected unclean shutdown - /data/db/mongod.lock is not empty.\n2020-05-02T12:46:04.058+0000 I  STORAGE  [initandlisten] Detected data files in /data/db created by the \'wiredTiger\' storage engine, so setting the active storage engine to \'wiredTiger\'.\n2020-05-02T12:46:04.058+0000 W  STORAGE  [initandlisten] Recovering data from the last clean checkpoint.\n2020-05-02T12:46:04.058+0000 I  STORAGE  [initandlisten] \n2020-05-02T12:46:04.058+0000 I  STORAGE  [initandlisten] ** WARNING: Using the XFS filesystem is strongly recommended with the WiredTiger storage engine\n2020-05-02T12:46:04.058+0000 I  STORAGE  [initandlisten] **          See http://dochub.mongodb.org/core/prodnotes-filesystem\n2020-05-02T12:46:04.058+0000 I  STORAGE  [initandlisten] \n2020-05-02T12:46:04.058+0000 I  STORAGE  [initandlisten] ** WARNING: The configured WiredTiger cache size is more than 80% of available RAM.\n2020-05-02T12:46:04.058+0000 I  STORAGE  [initandlisten] **          See http://dochub.mongodb.org/core/faq-memory-diagnostics-wt\n2020-05-02T12:46:04.058+0000 I  STORAGE  [initandlisten] wiredtiger_open config: create,cache_size=256M,cache_overflow=(file_max=0M),session_max=33000,eviction=(threads_min=4,threads_max=4),config_base=false,statistics=(fast),log=(enabled=true,archive=true,path=journal,compressor=snappy),file_manager=(close_idle_time=100000,close_scan_interval=10,close_handle_minimum=250),statistics_log=(wait=0),verbose=[recovery_progress,checkpoint_progress],\n2020-05-02T12:46:04.650+0000 I  STORAGE  [initandlisten] WiredTiger message [1588423564:650049][1:0x7f46cd25ab00], txn-recover: Recovering log 9 through 10\n2020-05-02T12:46:05.081+0000 I  STORAGE  [initandlisten] WiredTiger message [1588423565:81749][1:0x7f46cd25ab00], txn-recover: Recovering log 10 through 10\n2020-05-02T12:46:05.145+0000 I  STORAGE  [initandlisten] WiredTiger message [1588423565:145407][1:0x7f46cd25ab00], txn-recover: Main recovery loop: starting at 9/59015040 to 10/256\n2020-05-02T12:46:05.146+0000 I  STORAGE  [initandlisten] WiredTiger message [1588423565:146211][1:0x7f46cd25ab00], txn-recover: Recovering log 9 through 10\n2020-05-02T12:46:06.805+0000 I  STORAGE  [initandlisten] WiredTiger message [1588423566:805494][1:0x7f46cd25ab00], file:sizeStorer.wt, txn-recover: Recovering log 10 through 10\n2020-05-02T12:46:06.926+0000 I  STORAGE  [initandlisten] WiredTiger message [1588423566:925770][1:0x7f46cd25ab00], file:sizeStorer.wt, txn-recover: Set global recovery timestamp: (0, 0)\n2020-05-02T12:46:07.070+0000 I  RECOVERY [initandlisten] Wired ...

# %% [markdown]
# To stop it:

# %%
mongo_container.stop()

# %% [markdown]
# ## Connect using PyMongo

# %%
from pymongo import MongoClient
mongo_client = MongoClient('127.0.0.1', 27018)
db = mongo_client['data-prep']

# %%
mongo_client.server_info()
# Out:
# {'version': '4.2.5',
#  'gitVersion': '2261279b51ea13df08ae708ff278f0679c59dc32',
#  'modules': [],
#  'allocator': 'tcmalloc',
#  'javascriptEngine': 'mozjs',
#  'sysInfo': 'deprecated',
#  'versionArray': [4, 2, 5, 0],
#  'openssl': {'running': 'OpenSSL 1.1.1  11 Sep 2018',
#   'compiled': 'OpenSSL 1.1.1  11 Sep 2018'},
#  'buildEnvironment': {'distmod': 'ubuntu1804',
#   'distarch': 'x86_64',
#   'cc': '/opt/mongodbtoolchain/v3/bin/gcc: gcc (GCC) 8.2.0',
#   'ccflags': '-fno-omit-frame-pointer -fno-strict-aliasing -ggdb -pthread -Wall -Wsign-compare -Wno-unknown-pragmas -Winvalid-pch -Werror -O2 -Wno-unused-local-typedefs -Wno-unused-function -Wno-deprecated-declarations -Wno-unused-const-variable -Wno-unused-but-set-variable -Wno-missing-braces -fstack-protector-strong -fno-builtin-memcmp',
#   'cxx': '/opt/mongodbtoolchain/v3/bin/g++: g++ (GCC) 8.2.0',
#   'cxxflags': '-Woverloaded-virtual -Wno-maybe-uninitialized -fsized-deallocation -std=c++17',
#   'linkflags': '-pthread -Wl,-z,now -rdynamic -Wl,--fatal-warnings -fstack-protector-strong -fuse-ld=gold -Wl,--build-id -Wl,--hash-style=gnu -Wl,-z,noexecstack -Wl,--warn-execstack -Wl,-z,relro',
#   'target_arch': 'x86_64',
#   'target_os': 'linux'},
#  'bits': 64,
#  'debug': False,
#  'maxBsonObjectSize': 16777216,
#  'storageEngines': ['biggie', 'devnull', 'ephemeralForTest', 'wiredTiger'],
#  'ok': 1.0}

# %% [markdown]
# A note on why we need why the docker memory limit is not enough.
# We can see below that the databse thinks it can use all the host memory (see note in https://docs.mongodb.com/v3.2/reference/configuration-options/#storage.wiredTiger.engineConfig.cacheSizeGB).
# We need to limit manually how much memory it can take using the mongo.conf file.

# %%
db.command('hostInfo')['system']
# Out:
# {'currentTime': datetime.datetime(2020, 5, 3, 8, 34, 45, 646000),
#  'hostname': '3b67778f62f8',
#  'cpuAddrSize': 64,
#  'memSizeMB': 15829,
#  'memLimitMB': 512,
#  'numCores': 8,
#  'cpuArch': 'x86_64',
#  'numaEnabled': False}

# %% [markdown]
# ## Creating some random data

# %%
from datetime import date
import pandas as pd
from numpy.random import default_rng

rng = default_rng()

date_range = pd.date_range(
    end=date.today(),
    start=date.fromisoformat('1970-01-01'),
    freq='min',
    name='moment',
)
print(f'There is a total of {date_range.size} rows')
 
# Generate only a chunk at a time to avoid having thbe whole dataframe in memory
def generate_sample_chunk_df(chunk_size=100000):
    rows_count = date_range.size
    chunks_count = int(rows_count / chunk_size)
    print(f'There is {chunks_count} chunks')

    for i in range(chunks_count + 1):
        slice_begin = i * chunk_size
        if i <= chunks_count:
            slice_end = slice_begin + chunk_size - 1
        else:  # For the last chunk
            slice_end = slice_begin + 1 + rows_count % chunk_size

        chunk_date_range = date_range[slice_begin : slice_end]

        df = pd.DataFrame(index=chunk_date_range, columns=[])

        df['quantity'] = rng.integers(0, 1000, chunk_date_range.size)
        df['color'] = rng.choice(['black', 'white', 'purple', 'cyan'], chunk_date_range.size)

        # Creates the moment column from the index
        df.reset_index(inplace=True)

        # Creates an index column
        df.reset_index(inplace=True)
        df['index'] += slice_begin

        yield df

# The first chunk
g = generate_sample_chunk_df()
next(g)

# Wanna see the last one? use reversed(range(...)) in the generator
# Out:
# There is a total of 26474401 rows
# There is 26474 chunks

# %% [markdown]
# ### Inserting in mongo

# %%
# %%time
db.input_data.drop()

i = 0
for chunk in generate_sample_chunk_df():
    i += 1
    print(f'Inserting chunk {i}...')
    db.input_data.insert_many(chunk.to_dict(orient='record'))
# Out:
# There is 264 chunks
# Inserting chunk 1...
# Inserting chunk 2...
# Inserting chunk 3...
# Inserting chunk 4...
# Inserting chunk 5...
# Inserting chunk 6...
# Inserting chunk 7...
# Inserting chunk 8...
# Inserting chunk 9...
# Inserting chunk 10...
# Inserting chunk 11...
# Inserting chunk 12...
# Inserting chunk 13...
# Inserting chunk 14...
# Inserting chunk 15...
# Inserting chunk 16...
# Inserting chunk 17...
# Inserting chunk 18...
# Inserting chunk 19...
# Inserting chunk 20...
# Inserting chunk 21...
# Inserting chunk 22...
# Inserting chunk 23...
# Inserting chunk 24...
# Inserting chunk 25...
# Inserting chunk 26...
# Inserting chunk 27...
# Inserting chunk 28...
# Inserting chunk 29...
# Inserting chunk 30...
# Inserting chunk 31...
# Inserting chunk 32...
# Inserting chunk 33...
# Inserting chunk 34...
# Inserting chunk 35...
# Inserting chunk 36...
# Inserting chunk 37...
# Inserting chunk 38...
# Inserting chunk 39...
# Inserting chunk 40...
# Inserting chunk 41...
# Inserting chunk 42...
# Inserting chunk 43...
# Inserting chunk 44...
# Inserting chunk 45...
# Inserting chunk 46...
# Inserting chunk 47...
# Inserting chunk 48...
# Inserting chunk 49...
# Inserting chunk 50...
# Inserting chunk 51...
# Inserting chunk 52...
# Inserting chunk 53...
# Inserting chunk 54...
# Inserting chunk 55...
# Inserting chunk 56...
# Inserting chunk 57...
# Inserting chunk 58...
# Inserting chunk 59...
# Inserting chunk 60...
# Inserting chunk 61...
# Inserting chunk 62...
# Inserting chunk 63...
# Inserting chunk 64...
# Inserting chunk 65...
# Inserting chunk 66...
# Inserting chunk 67...
# Inserting chunk 68...
# Inserting chunk 69...
# Inserting chunk 70...
# Inserting chunk 71...
# Inserting chunk 72...
# Inserting chunk 73...
# Inserting chunk 74...
# Inserting chunk 75...
# Inserting chunk 76...
# Inserting chunk 77...
# Inserting chunk 78...
# Inserting chunk 79...
# Inserting chunk 80...
# Inserting chunk 81...
# Inserting chunk 82...
# Inserting chunk 83...
# Inserting chunk 84...
# Inserting chunk 85...
# Inserting chunk 86...
# Inserting chunk 87...
# Inserting chunk 88...
# Inserting chunk 89...
# Inserting chunk 90...
# Inserting chunk 91...
# Inserting chunk 92...
# Inserting chunk 93...
# Inserting chunk 94...
# Inserting chunk 95...
# Inserting chunk 96...
# Inserting chunk 97...
# Inserting chunk 98...
# Inserting chunk 99...
# Inserting chunk 100...
# Inserting chunk 101...
# Inserting chunk 102...
# Inserting chunk 103...
# Inserting chunk 104...
# Inserting chunk 105...
# Inserting chunk 106...
# Inserting chunk 107...
# Inserting chunk 108...
# Inserting chunk 109...
# Inserting chunk 110...
# Inserting chunk 111...
# Inserting chunk 112...
# Inserting chunk 113...
# Inserting chunk 114...
# Inserting chunk 115...
# Inserting chunk 116...
# Inserting chunk 117...
# Inserting chunk 118...
# Inserting chunk 119...
# Inserting chunk 120...
# Inserting chunk 121...
# Inserting chunk 122...
# Inserting chunk 123...
# Inserting chunk 124...
# Inserting chunk 125...
# Inserting chunk 126...
# Inserting chunk 127...
# Inserting chunk 128...
# Inserting chunk 129...
# Inserting chunk 130...
# Inserting chunk 131...
# Inserting chunk 132...
# Inserting chunk 133...
# Inserting chunk 134...
# Inserting chunk 135...
# Inserting chunk 136...
# Inserting chunk 137...
# Inserting chunk 138...
# Inserting chunk 139...
# Inserting chunk 140...
# Inserting chunk 141...
# Inserting chunk 142...
# Inserting chunk 143...
# Inserting chunk 144...
# Inserting chunk 145...
# Inserting chunk 146...
# Inserting chunk 147...
# Inserting chunk 148...
# Inserting chunk 149...
# Inserting chunk 150...
# Inserting chunk 151...
# Inserting chunk 152...
# Inserting chunk 153...
# Inserting chunk 154...
# Inserting chunk 155...
# Inserting chunk 156...
# Inserting chunk 157...
# Inserting chunk 158...
# Inserting chunk 159...
# Inserting chunk 160...
# Inserting chunk 161...
# Inserting chunk 162...
# Inserting chunk 163...
# Inserting chunk 164...
# Inserting chunk 165...
# Inserting chunk 166...
# Inserting chunk 167...
# Inserting chunk 168...
# Inserting chunk 169...
# Inserting chunk 170...
# Inserting chunk 171...
# Inserting chunk 172...
# Inserting chunk 173...
# Inserting chunk 174...
# Inserting chunk 175...
# Inserting chunk 176...
# Inserting chunk 177...
# Inserting chunk 178...
# Inserting chunk 179...
# Inserting chunk 180...
# Inserting chunk 181...
# Inserting chunk 182...
# Inserting chunk 183...
# Inserting chunk 184...
# Inserting chunk 185...
# Inserting chunk 186...
# Inserting chunk 187...
# Inserting chunk 188...
# Inserting chunk 189...
# Inserting chunk 190...
# Inserting chunk 191...
# Inserting chunk 192...
# Inserting chunk 193...
# Inserting chunk 194...
# Inserting chunk 195...
# Inserting chunk 196...
# Inserting chunk 197...
# Inserting chunk 198...
# Inserting chunk 199...
# Inserting chunk 200...
# Inserting chunk 201...
# Inserting chunk 202...
# Inserting chunk 203...
# Inserting chunk 204...
# Inserting chunk 205...
# Inserting chunk 206...
# Inserting chunk 207...
# Inserting chunk 208...
# Inserting chunk 209...
# Inserting chunk 210...
# Inserting chunk 211...
# Inserting chunk 212...
# Inserting chunk 213...
# Inserting chunk 214...
# Inserting chunk 215...
# Inserting chunk 216...
# Inserting chunk 217...
# Inserting chunk 218...
# Inserting chunk 219...
# Inserting chunk 220...
# Inserting chunk 221...
# Inserting chunk 222...
# Inserting chunk 223...
# Inserting chunk 224...
# Inserting chunk 225...
# Inserting chunk 226...
# Inserting chunk 227...
# Inserting chunk 228...
# Inserting chunk 229...
# Inserting chunk 230...
# Inserting chunk 231...
# Inserting chunk 232...
# Inserting chunk 233...
# Inserting chunk 234...
# Inserting chunk 235...
# Inserting chunk 236...
# Inserting chunk 237...
# Inserting chunk 238...
# Inserting chunk 239...
# Inserting chunk 240...
# Inserting chunk 241...
# Inserting chunk 242...
# Inserting chunk 243...
# Inserting chunk 244...
# Inserting chunk 245...
# Inserting chunk 246...
# Inserting chunk 247...
# Inserting chunk 248...
# Inserting chunk 249...
# Inserting chunk 250...
# Inserting chunk 251...
# Inserting chunk 252...
# Inserting chunk 253...
# Inserting chunk 254...
# Inserting chunk 255...
# Inserting chunk 256...
# Inserting chunk 257...
# Inserting chunk 258...
# Inserting chunk 259...
# Inserting chunk 260...
# Inserting chunk 261...
# Inserting chunk 262...
# Inserting chunk 263...
# Inserting chunk 264...
# Inserting chunk 265...
# CPU times: user 9min 35s, sys: 6.51 s, total: 9min 42s
# Wall time: 11min 33s

# %% [markdown]
# During this long operation, we can monitor that the mongo container never reach its limit:
# `docker stats`.

# %%
db.input_data.count_documents({})
# Out:
# 26472697

# %%
db.input_data.data_size()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-e96f60572423> in <module>
# ----> 1 db.input_data.data_size()
#
# ~/.pyenv/versions/3.8.2/envs/mongo-data-prep/lib/python3.8/site-packages/pymongo/collection.py in __call__(self, *args, **kwargs)
#    3338                             "exists." %
#    3339                             self.__name)
# -> 3340         raise TypeError("'Collection' object is not callable. If you meant to "
#    3341                         "call the '%s' method on a 'Collection' object it is "
#    3342                         "failing because no such method exists." %
#
# TypeError: 'Collection' object is not callable. If you meant to call the 'data_size' method on a 'Collection' object it is failing because no such method exists.

# %% [markdown]
# ### Running an aggregation

# %% [markdown]
# A simple aggregation on a subset (100 documents) is fast:

# %%
match_all = {
    '$match': {}
}

limit_100 = {
    '$limit': 100
}

add_year_field = {
    '$addFields': {
        'year': {'$year': '$moment'},
    }
}

aggregate_by_year = {
    '$group': {
        '_id': {
            'year': '$year'
        },
        'quantity': {'$avg': '$quantity'},
        'color': {'$first': '$color'},
        'start_index': {'$first': '$index'},
        'end_index': {'$last': '$index'},
    }
}

# %%
# %%time

list(db.input_data.aggregate([
    match_all,
    limit_100,
    add_year_field,
    aggregate_by_year,
]))
# Out:
# CPU times: user 6.07 ms, sys: 0 ns, total: 6.07 ms
# Wall time: 6.36 ms
# [{'_id': {'year': 1970},
#   'quantity': 507.17,
#   'color': 'cyan',
#   'start_index': 0,
#   'end_index': 99}]

# %% [markdown]
# But without the limit, it takes a while but does works without crashing anything:

# %%
# %%time

results = db.input_data.aggregate([
    match_all,
    add_year_field,
    aggregate_by_year,
])
# Out:
# CPU times: user 9.58 ms, sys: 6.6 ms, total: 16.2 ms
# Wall time: 51.6 s

# %%
pd.DataFrame(list(results))
# Out:
#                _id    quantity   color  start_index  end_index
# 0   {'year': 1985}  498.973548    cyan      7889760    8415359
# 1   {'year': 1977}  498.434233   white      3682080    4207679
# 2   {'year': 2001}  499.745214    cyan     16305120   16830719
# 3   {'year': 2009}  499.932941   white     20512800   21038399
# 4   {'year': 1998}  500.043629   black     14726880   15252479
# 5   {'year': 2015}  500.070008    cyan     23667840   24193439
# 6   {'year': 2020}  498.643856  purple     26297280   26472960
# 7   {'year': 1988}  498.907750    cyan      9466560    9993599
# 8   {'year': 2013}  499.772079    cyan     22616640   23142239
# 9   {'year': 2016}  498.678129    cyan     24193440   24720479
# 10  {'year': 2018}  498.623556   black     25246080   25771679
# 11  {'year': 2000}  499.776117    cyan     15778080   16305119
# 12  {'year': 1976}  499.533788   black      3155040    3682079
# 13  {'year': 1973}  500.543646    cyan      1578240    2103839
# 14  {'year': 1972}  499.141046  purple      1051200    1578239
# 15  {'year': 1989}  499.346281  purple      9993600   10519199
# 16  {'year': 2006}  499.377353   white     18934560   19460159
# 17  {'year': 1995}  499.431144   black     13148640   13674239
# 18  {'year': 1974}  499.409087  purple      2103840    2629439
# 19  {'year': 1997}  499.998862   black     14201280   14726879
# 20  {'year': 1990}  499.034372   white     10519200   11044799
# 21  {'year': 2008}  499.854656   white     19985760   20512799
# 22  {'year': 2012}  499.139361  purple     22089600   22616639
# 23  {'year': 1978}  499.993917   white      4207680    4733279
# 24  {'year': 1986}  499.575401   white      8415360    8940959
# 25  {'year': 1979}  499.251041   white      4733280    5258879
# 26  {'year': 1987}  500.354248   black      8940960    9466559
# 27  {'year': 2003}  499.356864   black     17356320   17881919
# 28  {'year': 1975}  499.450098  purple      2629440    3155039
# 29  {'year': 2005}  499.600386    cyan     18408960   18934559
# 30  {'year': 2002}  499.513148    cyan     16830720   17356319
# 31  {'year': 1994}  499.477824    cyan     12623040   13148639
# 32  {'year': 1981}  500.114881   white      5785920    6311519
# 33  {'year': 2007}  499.624441   white     19460160   19985759
# 34  {'year': 2017}  499.946225    cyan     24720480   25246079
# 35  {'year': 1984}  500.129767   black      7362720    7889759
# 36  {'year': 1991}  499.189576   white     11044800   11570399
# 37  {'year': 2011}  499.554568    cyan     21564000   22089599
# 38  {'year': 2019}  499.575921    cyan     25771680   26297279
# 39  {'year': 1970}  499.291251    cyan            0     525599
# 40  {'year': 1971}  499.710452    cyan       525600    1051199
# 41  {'year': 1983}  499.869877   black      6837120    7362719
# 42  {'year': 1993}  500.214987    cyan     12097440   12623039
# 43  {'year': 1999}  499.623001   white     15252480   15778079
# 44  {'year': 2004}  499.565861   black     17881920   18408959
# 45  {'year': 1982}  499.715810   black      6311520    6837119
# 46  {'year': 2010}  499.184220  purple     21038400   21563999
# 47  {'year': 2014}  499.631707   black     23142240   23667839
# 48  {'year': 1992}  499.459823   black     11570400   12097439
# 49  {'year': 1996}  499.471182    cyan     13674240   14201279
# 50  {'year': 1980}  499.906082    cyan      5258880    5785919

# %% [markdown]
# Note the weird order of results! MongoDB docs states that documents are not sorted after a `$group` stage.

# %% [markdown]
# Conclusion: the memory limit really protects the mongo process. It takes all the CPU time of the container, so it'll be required to test if only one core is used in full or if the whole mongo server will become unresponsive.

# %% [markdown]
# Let's try an aggregation with many more documents:

# %%
add_hourly_field = {
    '$addFields': {
        'year': {'$year': '$moment'},
        'month': {'$month': '$moment'},
        'day': {'$dayOfMonth': '$moment'},
        'hour': {'$hour': '$moment'},
    }
}

aggregate_by_hour = {
    '$group': {
        '_id': {
            'year': '$year',
            'month': '$month',
            'day': '$day',
            'hour': '$hour',
        },
        'quantity': {'$avg': '$quantity'},
        'color': {'$first': '$color'},
        'start_index': {'$first': '$index'},
        'end_index': {'$last': '$index'},
    }
}

# %%
# %%time
results = db.input_data.aggregate([
    match_all,
    add_hourly_field,
    aggregate_by_hour,
])
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/.pyenv/versions/3.8.2/envs/mongo-data-prep/lib/python3.8/site-packages/pymongo/collection.py in aggregate(self, pipeline, session, **kwargs)
#    2372             https://docs.mongodb.com/manual/reference/command/aggregate
#    2373         """
# -> 2374         with self.__database.client._tmp_session(session, close=False) as s:
#    2375             return self._aggregate(_CollectionAggregationCommand,
#    2376                                    pipeline,
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# ~/.pyenv/versions/3.8.2/envs/mongo-data-prep/lib/python3.8/site-packages/pymongo/mongo_client.py in _tmp_session(self, session, close)
#    1821             return
#    1822
# -> 1823         s = self._ensure_session(session)
#    1824         if s and close:
#    1825             with s:
#
# ~/.pyenv/versions/3.8.2/envs/mongo-data-prep/lib/python3.8/site-packages/pymongo/mongo_client.py in _ensure_session(self, session)
#    1808             # Don't make implicit sessions causally consistent. Applications
#    1809             # should always opt-in.
# -> 1810             return self.__start_session(True, causal_consistency=False)
#    1811         except (ConfigurationError, InvalidOperation):
#    1812             # Sessions not supported, or multiple users authenticated.
#
# ~/.pyenv/versions/3.8.2/envs/mongo-data-prep/lib/python3.8/site-packages/pymongo/mongo_client.py in __start_session(self, implicit, **kwargs)
#    1761
#    1762         # Raises ConfigurationError if sessions are not supported.
# -> 1763         server_session = self._get_server_session()
#    1764         opts = client_session.SessionOptions(**kwargs)
#    1765         return client_session.ClientSession(
#
# ~/.pyenv/versions/3.8.2/envs/mongo-data-prep/lib/python3.8/site-packages/pymongo/mongo_client.py in _get_server_session(self)
#    1794     def _get_server_session(self):
#    1795         """Internal: start or resume a _ServerSession."""
# -> 1796         return self._topology.get_server_session()
#    1797
#    1798     def _return_server_session(self, server_session, lock):
#
# ~/.pyenv/versions/3.8.2/envs/mongo-data-prep/lib/python3.8/site-packages/pymongo/topology.py in get_server_session(self)
#     480                 if self._description.topology_type == TOPOLOGY_TYPE.Single:
#     481                     if not self._description.has_known_servers:
# --> 482                         self._select_servers_loop(
#     483                             any_server_selector,
#     484                             self._settings.server_selection_timeout,
#
# ~/.pyenv/versions/3.8.2/envs/mongo-data-prep/lib/python3.8/site-packages/pymongo/topology.py in _select_servers_loop(self, selector, timeout, address)
#     206             # No suitable servers.
#     207             if timeout == 0 or now > end_time:
# --> 208                 raise ServerSelectionTimeoutError(
#     209                     self._error_message(selector))
#     210
#
# ServerSelectionTimeoutError: 127.0.0.1:27018: [Errno 111] Connection refused

# %% [markdown]
# Fails with `OperationFailure: Exceeded memory limit for $group, but didn't allow external sort. Pass allowDiskUse:true to opt in.`
#
# Two things next:
# - first, let's enable the `allowDiskUse`
# - second, let's write the output in another collection
#
# We do not want data to get out of the db to our pymongo client, for it will deplete our host's memory.

# %%
write_in_output_collection = {
    '$out': 'output_data'
}

# %%
# %%time

results = db.input_data.aggregate([
    match_all,
    add_hourly_field,
    aggregate_by_hour,
    write_in_output_collection
], allowDiskUse=True)
# Out:
# CPU times: user 34.7 ms, sys: 10.9 ms, total: 45.6 ms
# Wall time: 1min 33s

# %%
r = db.output_data.find({})
r[0]
# Out:
# {'_id': {'year': 1970, 'month': 1, 'day': 1, 'hour': 0},
#  'quantity': 501.65,
#  'color': 'cyan',
#  'start_index': 0,
#  'end_index': 59}

# %% [markdown]
# Note: this seems to indicate we could monitor the process by having a second command querying for the output results: https://stackoverflow.com/questions/22725814/view-progress-of-long-running-mongodb-aggregation-job
